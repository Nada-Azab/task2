# %%
# import libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

# %% [markdown]
# #### Acces to drive to get data

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! unzip /content/drive/MyDrive/Data_companies.zip
# Out:
# Archive:  /content/drive/MyDrive/Data_companies.zip
# replace companies.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: companies.csv

# %% [markdown]
# #### Reading and explore data

# %%
data=pd.read_csv('/content/companies.csv')
data.head()
# Out:
#         id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0      c:1             0     Company          1        NaN
# 1     c:10             1     Company         10        NaN
# 2    c:100             2     Company        100        NaN
# 3  c:10000             3     Company      10000        NaN
# 4  c:10001             4     Company      10001        NaN
#
#                  name     normalized_name                    permalink  \
# 0            Wetpaint            wetpaint            /company/wetpaint
# 1             Flektor             flektor             /company/flektor
# 2               There               there               /company/there
# 3             MYWEBBO             mywebbo             /company/mywebbo
# 4  THE Movie Streamer  the movie streamer  /company/the-movie-streamer
#
#      category_code     status  ... first_milestone_at last_milestone_at  \
# 0              web  operating  ...         2010-09-05        2013-09-18
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196553 entries, 0 to 196552
# Data columns (total 44 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   196553 non-null  object
#  1   Unnamed: 0.1         196553 non-null  int64
#  2   entity_type          196553 non-null  object
#  3   entity_id            196553 non-null  int64
#  4   parent_id            0 non-null       float64
#  5   name                 196531 non-null  object
#  6   normalized_name      196527 non-null  object
#  7   permalink            196553 non-null  object
#  8   category_code        123186 non-null  object
#  9   status               196553 non-null  object
#  10  founded_at           91227 non-null   object
#  11  closed_at            2620 non-null    object
#  12  domain               126545 non-null  object
#  13  homepage_url         126545 non-null  object
#  14  twitter_username     80591 non-null   object
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0.1      entity_id  parent_id     logo_width    logo_height  \
# count  196553.000000  196553.000000        0.0  110110.000000  110110.000000
# mean    98276.000000  153006.227333        NaN     459.132685     222.728917
# std     56740.108067   90209.250941        NaN     594.982577     333.090722
# min         0.000000       1.000000        NaN       1.000000       1.000000
# 25%     49138.000000   59850.000000        NaN     192.000000      70.000000
# 50%     98276.000000  174539.000000        NaN     267.000000     105.000000
# 75%    147414.000000  232655.000000        NaN     484.000000     232.000000
# max    196552.000000  286215.000000        NaN   18200.000000    9600.000000
#
#        investment_rounds  invested_companies  funding_rounds  \
# count        2591.000000         2591.000000    31707.000000
# mean            2.372057            2.204940        1.659760
# std            12.173510           11.436955        1.201666
# ...

# %% [markdown]
# ## **preprocess for data**

# %% [markdown]
# * Checking the percentage of NaN(null values) values present in each feature
# * Removing duplicates
# * Dropping columns which have NaN values.
# * Remove unnecessary and corrupted data.
# * Data Labelling.

# %% [markdown]
# ### Romving unnecessary features:

# %%
data.iloc[:,28:]
# Out:
#         investment_rounds  invested_companies first_funding_at  \
# 0                     NaN                 NaN       2005-10-01
# 1                     NaN                 NaN              NaN
# 2                     NaN                 NaN              NaN
# 3                     NaN                 NaN              NaN
# 4                     NaN                 NaN              NaN
# ...                   ...                 ...              ...
# 196548                NaN                 NaN              NaN
# 196549                NaN                 NaN       2008-08-25
# 196550                NaN                 NaN              NaN
# 196551                NaN                 NaN              NaN
# 196552                NaN                 NaN       2008-06-01
#
#        last_funding_at  funding_rounds  funding_total_usd first_milestone_at  \
# 0           2008-05-19             3.0         39750000.0         2010-09-05
# ...

# %%
data.drop(axis=1,columns=['id','Unnamed: 0.1','name','permalink','domain','homepage_url','logo_url'],inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196553 entries, 0 to 196552
# Data columns (total 37 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   entity_type          196553 non-null  object
#  1   entity_id            196553 non-null  int64
#  2   parent_id            0 non-null       float64
#  3   normalized_name      196527 non-null  object
#  4   category_code        123186 non-null  object
#  5   status               196553 non-null  object
#  6   founded_at           91227 non-null   object
#  7   closed_at            2620 non-null    object
#  8   twitter_username     80591 non-null   object
#  9   logo_width           110110 non-null  float64
#  10  logo_height          110110 non-null  float64
#  11  short_description    7131 non-null    object
#  12  description          92048 non-null   object
#  13  overview             126971 non-null  object
# ...

# %% [markdown]
# ### Checking the percentage of NaN(null values) values present in each feature

# %%
for col,null in enumerate(data.isnull().sum()):
  print(data.columns.values[col]," :",np.int(null/len(data)*100))
# Out:
# entity_type  : 0
# entity_id  : 0
# parent_id  : 100
# normalized_name  : 0
# category_code  : 37
# status  : 0
# founded_at  : 53
# closed_at  : 98
# twitter_username  : 58
# logo_width  : 43
# logo_height  : 43
# short_description  : 96
# description  : 53
# overview  : 35
# tag_list  : 58
# country_code  : 55
# state_code  : 74
# city  : 57
# region  : 0
# first_investment_at  : 98
# last_investment_at  : 98
# investment_rounds  : 98
# invested_companies  : 98
# first_funding_at  : 83
# last_funding_at  : 83
# funding_rounds  : 83
# funding_total_usd  : 85
# first_milestone_at  : 53
# last_milestone_at  : 53
# milestones  : 53
# relationships  : 34
# created_by  : 20
# created_at  : 0
# updated_at  : 0
# lat  : 57
# lng  : 57
# ROI  : 99
# ...

# %% [markdown]
# ### Dropping columns which have NaN values.

# %%
drop_list=[]
for col,null in enumerate(data.isnull().sum()):
    if (np.int(null/len(data)*100)) >50 :
       drop_list.append(data.columns.values[col])
# Out:
# <ipython-input-124-520c6dcc8db5>:3: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if (np.int(null/len(data)*100)) >50 :

# %%
drop_list
# Out:
# ['parent_id',
#  'founded_at',
#  'closed_at',
#  'twitter_username',
#  'short_description',
#  'description',
#  'tag_list',
#  'country_code',
#  'state_code',
#  'city',
#  'first_investment_at',
#  'last_investment_at',
#  'investment_rounds',
#  'invested_companies',
#  'first_funding_at',
#  'last_funding_at',
#  'funding_rounds',
#  'funding_total_usd',
#  'first_milestone_at',
#  'last_milestone_at',
#  'milestones',
#  'lat',
#  'lng',
#  'ROI']

# %%
data.drop(axis=1,columns=drop_list,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196553 entries, 0 to 196552
# Data columns (total 13 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   entity_type      196553 non-null  object
#  1   entity_id        196553 non-null  int64
#  2   normalized_name  196527 non-null  object
#  3   category_code    123186 non-null  object
#  4   status           196553 non-null  object
#  5   logo_width       110110 non-null  float64
#  6   logo_height      110110 non-null  float64
#  7   overview         126971 non-null  object
#  8   region           196553 non-null  object
#  9   relationships    129667 non-null  float64
#  10  created_by       155533 non-null  object
#  11  created_at       196553 non-null  object
#  12  updated_at       196553 non-null  object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 19.5+ MB

# %% [markdown]
# ### Removing duplicates

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Data Labelling

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 196553 entries, 0 to 196552
# Data columns (total 13 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   entity_type      196553 non-null  object
#  1   entity_id        196553 non-null  int64
#  2   normalized_name  196527 non-null  object
#  3   category_code    123186 non-null  object
#  4   status           196553 non-null  object
#  5   logo_width       110110 non-null  float64
#  6   logo_height      110110 non-null  float64
#  7   overview         126971 non-null  object
#  8   region           196553 non-null  object
#  9   relationships    129667 non-null  float64
#  10  created_by       155533 non-null  object
#  11  created_at       196553 non-null  object
#  12  updated_at       196553 non-null  object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 21.0+ MB

# %%
for i in data.columns:
  if data[i].dtype =='object' :
    print(i,len(data[i].unique()),'\n')
# Out:
# entity_type 1
#
# normalized_name 195452
#
# category_code 43
#
# status 4
#
# overview 126516
#
# region 5847
#
# created_by 55330
#
# created_at 182851
#
# updated_at 183558

# %%
for i in data.columns:
  if data[i].dtype =='object' :
    print(i,(data[i].unique()),'\n')
# Out:
# entity_type ['Company']
#
# normalized_name ['wetpaint' 'flektor' 'there' ... 'csc' 'top candidate' 'closet couture']
#
# category_code ['web' 'games_video' 'network_hosting' 'advertising' 'cleantech' nan
#  'enterprise' 'other' 'consulting' 'mobile' 'health' 'software'
#  'analytics' 'finance' 'education' 'medical' 'manufacturing' 'biotech'
#  'ecommerce' 'public_relations' 'hardware' 'search' 'news' 'government'
#  'security' 'photo_video' 'travel' 'semiconductor' 'social' 'legal'
#  'transportation' 'hospitality' 'sports' 'nonprofit' 'fashion' 'messaging'
#  'music' 'automotive' 'design' 'real_estate' 'local' 'nanotech' 'pets']
#
# status ['operating' 'acquired' 'closed' 'ipo']
#
# overview ['Wetpaint is a technology platform company that uses its proprietary state-of-the-art technology and expertise in social media to build and monetize audiences for digital publishers. Wetpaint'
# ...

# %%
data.drop(inplace =True,columns=['entity_type','normalized_name'],axis=1)

# %%
data['created_at'] =pd.to_datetime(data['created_at'])

# %%
len(data['created_at'].unique())
# Out:
# 182851

# %%
# Extract year, month, and day into separate columns
data['year'] = data['created_at'].dt.year
data['month'] = data['created_at'].dt.month
data['day'] = data['created_at'].dt.day

# %%
data.drop(inplace =True,columns='created_at',axis=1)

# %%
data['updated_at'] =pd.to_datetime(data['updated_at'])
# Extract year, month, and day into separate columns
data['year_up'] = data['updated_at'].dt.year
data['month_up'] = data['updated_at'].dt.month
data['day_up'] = data['updated_at'].dt.day

data.drop(inplace =True,columns='updated_at',axis=1)

# %%
data.drop(columns=['created_by','logo_width','logo_height','entity_id','overview'],inplace=True,axis=1)

# %%
# region,status
data.head()
# Out:
#      category_code     status       region  relationships  year  month  day  \
# 0              web  operating      Seattle           17.0  2007      5   25
# 1      games_video   acquired  Los Angeles            6.0  2007      5   31
# 2      games_video   acquired       SF Bay           12.0  2007      8    6
# 3  network_hosting  operating      unknown            NaN  2008      8   24
# 4      games_video  operating      unknown            NaN  2008      8   24
#
#    year_up  month_up  day_up
# 0     2013         4      13
# 1     2008         5      23
# 2     2013        11       4
# 3     2008         9       6
# 4     2008         9       6

# %%
data=pd.get_dummies(data)
